# %%
from util.dbmod import *
from util.linreg import *
import numpy as np, matplotlib.pyplot as plt, pandas as pd

# %%
file_name = '../data/P7132038_32.csv'
file_name_csv = file_name[8:19]

# %%
c.execute("SELECT time FROM " + file_name_csv)
x = np.array([line[0] for line in c])

c.execute("SELECT frequency FROM " + file_name_csv)
y = np.array([line[0] for line in c])

# %%
get_linreg(x, y)
# Out:
# y-intercept: -8.075144
# slope: 6130.239814
# linear regression line: predicted y = -8.075144 + 6130.239814x
